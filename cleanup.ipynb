# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
def build(train):
    loanDB = pd.read_csv('data/loanUnitedTrain.csv') if train else pd.read_csv('data/loanUnitedTest.csv')
    drops = [
     "birthday",
     "account_creation",
     "account_frequency", 
     "card issue"
    ]

    drops_subsstrs = [
     "date", 
     "code", 
     "region",
     "no. of municipalities with inhabitants", 
     "no. of cities", 
     "client_district"
    ]

    drops += [c for c in loanDB.columns if True in [s in c for s in drops_subsstrs]]
    final = loanDB.drop(columns=drops)
    final["card_type"] = final["card_type"].map({"no card": 0, "junior": 1, "classic":2, "gold":3})
    final.to_csv("data/final_loan_"+("train" if train else "test")+".csv", index=False)
    return final

# %%
build(train=True)
# Out:
#      loan_id  loan_value  loan_duration  payments  loan_success  \
# 0       5314       96396             12      8033            -1
# 1       5316      165960             36      4610             1
# 2       6863      127080             60      2118             1
# 3       5325      105804             36      2939             1
# 4       7240      274740             60      4579             1
# ..       ...         ...            ...       ...           ...
# 323     6818      155616             48      3242             1
# 324     5625      222180             60      3703            -1
# 325     6805       45024             48       938             1
# 326     7233      115812             36      3217             1
# 327     7308      129408             24      5392             1
#
#      account_district no. of inhabitants  \
# 0                                  94812
# 1                                 112709
# 2                                  77917
# 3                                 107870
# 4                                1204953
# ..                                   ...
# 323                               226122
# 324                                45714
# 325                               285387
# 326                                93931
# 327                               106054
#
#      account_district ratio of urban inhabitants   \
# 0                                            81.8
# 1                                            73.5
# 2                                            53.5
# 3                                            58.0
# 4                                           100.0
# ..                                            ...
# 323                                          62.6
# 324                                          55.6
# 325                                          89.9
# 326                                          56.9
# 327                                          63.1
#
#      account_district average salary   \
# 0                                9650
# 1                                8369
# 2                                8390
# 3                                8754
# 4                               12541
# ..                                ...
# 323                              8994
# 324                              8843
# 325                             10177
# 326                              8427
# 327                              8110
#
#      account_district unemploymant rate '95   \
# 0                                       6.43
# 1                                       6.43
# 2                                       6.43
# 3                                       6.43
# 4                                       6.43
# ..                                       ...
# 323                                     6.43
# 324                                     6.43
# 325                                     6.43
# 326                                     6.43
# 327                                     6.43
#
#      account_district unemploymant rate '96   ...  card_type  \
# 0                                       3.67  ...          0
# 1                                       2.31  ...          0
# 2                                       2.89  ...          0
# 3                                       4.31  ...          0
# 4                                       0.43  ...          0
# ..                                       ...  ...        ...
# 323                                     4.79  ...          0
# 324                                     3.60  ...          0
# 325                                     7.75  ...          0
# 326                                     1.54  ...          0
# 327                                     6.55  ...          0
#
#      no. of transactions  balance  nr_movements  min_trans_amount  \
# 0                 3300.0  20100.0           4.0            1100.0
# 1                 3419.0  52208.9          37.0               2.9
# 2                12000.0  20272.8          24.0              48.6
# 3                   14.6  34292.7          25.0              14.6
# 4                  182.8  41142.9          27.0              30.0
# ..                   ...      ...           ...               ...
# 323              14600.0  60694.1         172.0              14.6
# 324               6900.0  59578.8          59.0              14.6
# 325              17800.0  38384.3          39.0              14.6
# 326               3100.0  41878.1         124.0              14.6
# 327               4780.0  24199.5         107.0              14.6
#
#      max_trans_amount  avg_trans_amount  min_balance  max_balance  \
# 0              9900.0       5025.000000       1100.0      20100.0
# 1             54300.0      11015.635135        700.0     120512.8
# 2             19065.0       5417.458333        800.0      49590.4
# 3             26448.0       8253.080000       1000.0      65898.5
# 4             63366.0      18945.966667        600.0     122893.1
# ..                ...               ...          ...          ...
# 323           36960.0       4895.974419        200.0      75294.1
# 324           52600.0      11725.494915        800.0     130659.1
# 325           31636.5       7779.815385        800.0      63659.3
# 326           50800.0      13280.084677       1100.0     119527.2
# 327           24212.0       4550.302804       1000.0      56055.6
#
#       avg_balance
# 0    12250.000000
# 1    52083.859459
# 2    30060.954167
# 3    41297.480000
# 4    57188.211111
# ..            ...
# 323  44197.509884
# 324  55230.444068
# 325  41994.907692
# 326  56646.516129
# 327  30869.781308
#
# [328 rows x 25 columns]

# %%
build(train=False)
# Out:
#      loan_id  loan_value  loan_duration  payments  loan_success  \
# 0       5895       93960             60      1566           NaN
# 1       7122      260640             36      7240           NaN
# 2       6173      232560             48      4845           NaN
# 3       6142      221880             60      3698           NaN
# 4       5358       38520             12      3210           NaN
# ..       ...         ...            ...       ...           ...
# 349     4989      352704             48      7348           NaN
# 350     5221       52512             12      4376           NaN
# 351     6402      139488             24      5812           NaN
# 352     5346       55632             24      2318           NaN
# 353     6748      240900             60      4015           NaN
#
#      account_district no. of inhabitants  \
# 0                                  77917
# 1                                  58400
# 2                                 177686
# 3                                  81344
# 4                                  95907
# ..                                   ...
# 349                               103347
# 350                               157042
# 351                                75232
# 352                               285387
# 353                               110643
#
#      account_district ratio of urban inhabitants   \
# 0                                            53.5
# 1                                            52.4
# 2                                            74.8
# 3                                            55.3
# 4                                            59.1
# ..                                            ...
# 349                                          67.0
# 350                                          33.9
# 351                                          41.7
# 352                                          89.9
# 353                                          51.9
#
#      account_district average salary   \
# 0                                8390
# 1                                8620
# 2                               10045
# 3                                8899
# 4                                8388
# ..                                ...
# 349                              9104
# 350                              8743
# 351                              8980
# 352                             10177
# 353                              8441
#
#      account_district unemploymant rate '95   \
# 0                                       6.43
# 1                                       6.43
# 2                                       6.43
# 3                                       6.43
# 4                                       6.43
# ..                                       ...
# 349                                     6.43
# 350                                     6.43
# 351                                     6.43
# 352                                     6.43
# 353                                     6.43
#
#      account_district unemploymant rate '96   ...  card_type  \
# 0                                       2.89  ...          0
# 1                                       1.25  ...          0
# 2                                       1.71  ...          0
# 3                                       3.97  ...          0
# 4                                       2.94  ...          0
# ..                                       ...  ...        ...
# 349                                     2.07  ...          2
# 350                                     2.43  ...          0
# 351                                     2.21  ...          0
# 352                                     7.75  ...          0
# 353                                     4.48  ...          0
#
#      no. of transactions  balance  nr_movements  min_trans_amount  \
# 0                19700.0  49548.5          89.0              14.6
# 1                12284.0  11565.4          78.0               4.6
# 2                 2692.0  45754.0         176.0              45.7
# 3                  323.0  41785.4          71.0               2.0
# 4                 2520.0  13994.3         114.0              14.6
# ..                   ...      ...           ...               ...
# 349              12100.0  35875.3          56.0              14.6
# 350                 14.6  41035.4          87.0              10.9
# 351              25500.0  47956.3         104.0              30.0
# 352                 14.6  38449.2         114.0              14.6
# 353               8919.0  19813.8         120.0              14.6
#
#      max_trans_amount  avg_trans_amount  min_balance  max_balance  \
# 0             36637.5       8051.737079        800.0      88246.7
# 1             41871.0       6935.733333       -718.6      88731.8
# 2             43605.0       7217.385795        200.0      79286.6
# 3             33280.0       6430.809859       1000.0      74216.8
# 4              8800.0       2373.266667        900.0      31302.0
# ..                ...               ...          ...          ...
# 349           49101.0       8582.460714        800.0      74693.6
# 350           49972.0      12491.751724       1000.0     120419.7
# 351           52305.0      13016.101923       1100.0      95976.0
# 352           23522.0       6040.260526        500.0      52896.1
# 353           25394.0       5047.062500        700.0      59731.2
#
#       avg_balance
# 0    54520.202247
# 1    31518.182051
# 2    40175.612500
# 3    44440.912676
# 4    20231.313158
# ..            ...
# 349  30797.487500
# 350  59684.298851
# 351  46755.305769
# 352  29645.320175
# 353  26268.190000
#
# [354 rows x 25 columns]
